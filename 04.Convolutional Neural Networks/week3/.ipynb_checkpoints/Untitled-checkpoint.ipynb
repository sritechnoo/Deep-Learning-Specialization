# %%
# !tar chvzf notebook.tar.gz --exclude notebook.tar.gz *
# Out:
# Car detection for Autonomous Driving/
# Car detection for Autonomous Driving/out/
# Car detection for Autonomous Driving/out/test.jpg
# Car detection for Autonomous Driving/Autonomous driving application - Car detection - v2.ipynb
# Car detection for Autonomous Driving/model_data/
# Car detection for Autonomous Driving/model_data/object_classes.txt
# Car detection for Autonomous Driving/model_data/yolo.h5
# Car detection for Autonomous Driving/model_data/yolo_anchors.txt
# Car detection for Autonomous Driving/model_data/coco_classes.txt
# Car detection for Autonomous Driving/yolo_utils.py
# Car detection for Autonomous Driving/.ipynb_checkpoints/
# Car detection for Autonomous Driving/.ipynb_checkpoints/Autonomous driving application - Car detection - v1-checkpoint.ipynb
# Car detection for Autonomous Driving/.ipynb_checkpoints/Autonomous driving application - Car detection - v3-checkpoint.ipynb
# ...
